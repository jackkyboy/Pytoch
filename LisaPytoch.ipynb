# %%
pip install torch==1.10.1 torchvision==0.11.2 torchaudio==0.10.1
# Out:
# Requirement already satisfied: torch==1.10.1 in ./opt/anaconda3/lib/python3.9/site-packages (1.10.1)
# Requirement already satisfied: torchvision==0.11.2 in ./opt/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: torchaudio==0.10.1 in ./opt/anaconda3/lib/python3.9/site-packages (0.10.1)
# Requirement already satisfied: typing-extensions in ./opt/anaconda3/lib/python3.9/site-packages (from torch==1.10.1) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in ./opt/anaconda3/lib/python3.9/site-packages (from torchvision==0.11.2) (8.4.0)
# Requirement already satisfied: numpy in ./opt/anaconda3/lib/python3.9/site-packages (from torchvision==0.11.2) (1.20.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# %%
from PIL import Image

# %%
img = Image.open('/Users/apichet/lisa.jpg').convert("RGB")
out = face2paint(model, img)

# %%
from pylab import rcParams

# %%
import matplotlib.pyplot as plt

# %%
rcParams['figure.figsize'] = 11 ,8
fig, ax = plt.subplots(1,2)
ax[0].imshow(img)
ax[1].imshow(out)
plt.show()
